# %%
# Python
import pandas as pd
from tqdm import tqdm
import time
import matplotlib.pyplot as plt
from prophet import Prophet
import mysql
import mysql.connector
import pymysql
import joblib
import dyplot
from datetime import datetime

# %%
query = f"""SELECT fecha,tmed
FROM valores_climatologicos
"""

# %%
database = "AEMET"

db = mysql.connector.connect(host     = "localhost",
                             user     = "root",
                             password = "nueva_contraseña",
                             database = database)

cursor = db.cursor()

cursor.execute(query) # Ejecutamos la query
column_names = cursor.column_names # Nombre de las columnas de la tabla

# Guardamos los datos de la tabla
data = cursor.fetchall()


df = pd.DataFrame(data, columns = column_names)

cursor.close()
db.close()

# %%
df["fecha"] = pd.to_datetime(df["fecha"])

# %% [markdown]
# # SEMESTRAL:

# %%
df['semestre'] = df['fecha'].apply(lambda x: pd.Timestamp(year=x.year, month=(1 if x.month <= 6 else 7), day=1))
df["semestre"].unique()
# Out:
# <DatetimeArray>
# ['2013-01-01 00:00:00', '2013-07-01 00:00:00', '2014-01-01 00:00:00',
#  '2014-07-01 00:00:00', '2015-01-01 00:00:00', '2015-07-01 00:00:00',
#  '2017-01-01 00:00:00', '2017-07-01 00:00:00', '2018-01-01 00:00:00',
#  '2018-07-01 00:00:00', '2019-01-01 00:00:00', '2019-07-01 00:00:00',
#  '2020-01-01 00:00:00', '2020-07-01 00:00:00', '2021-01-01 00:00:00',
#  '2021-07-01 00:00:00', '2022-01-01 00:00:00', '2022-07-01 00:00:00',
#  '2023-01-01 00:00:00', '2023-07-01 00:00:00', '2024-01-01 00:00:00',
#  '2024-07-01 00:00:00', '2016-01-01 00:00:00', '2016-07-01 00:00:00']
# Length: 24, dtype: datetime64[ns]

# %%
df_biannual = df.groupby("semestre").agg({"tmed":"mean"}).reset_index()

# %%
df_biannual
# Out:
#      semestre       tmed
# 0  2013-01-01  11.939553
# 1  2013-07-01  17.126592
# 2  2014-01-01  13.323046
# 3  2014-07-01  17.316944
# 4  2015-01-01  13.221510
# 5  2015-07-01  17.887790
# 6  2016-01-01  12.880579
# 7  2016-07-01  17.641331
# 8  2017-01-01  13.928824
# 9  2017-07-01  17.359126
# 10 2018-01-01  12.324507
# 11 2018-07-01  17.576688
# 12 2019-01-01  13.015025
# 13 2019-07-01  17.625057
# 14 2020-01-01  13.869420
# 15 2020-07-01  17.431901
# 16 2021-01-01  13.057936
# 17 2021-07-01  17.202520
# 18 2022-01-01  13.556550
# 19 2022-07-01  18.893737
# 20 2023-01-01  13.796390
# 21 2023-07-01  18.490756
# 22 2024-01-01  13.901692
# 23 2024-07-01  21.149441

# %%
def preparar_data(df,column1, column2):

    df = df[[column1, column2]]
    df.rename(columns={column1: "ds", column2: "y"}, inplace=True)
    
    return df

# %%
df_biannual = preparar_data(df_biannual,"semestre","tmed")

# %%
df_biannual
# Out:
#            ds          y
# 0  2013-01-01  11.939553
# 1  2013-07-01  17.126592
# 2  2014-01-01  13.323046
# 3  2014-07-01  17.316944
# 4  2015-01-01  13.221510
# 5  2015-07-01  17.887790
# 6  2016-01-01  12.880579
# 7  2016-07-01  17.641331
# 8  2017-01-01  13.928824
# 9  2017-07-01  17.359126
# 10 2018-01-01  12.324507
# 11 2018-07-01  17.576688
# 12 2019-01-01  13.015025
# 13 2019-07-01  17.625057
# 14 2020-01-01  13.869420
# 15 2020-07-01  17.431901
# 16 2021-01-01  13.057936
# 17 2021-07-01  17.202520
# 18 2022-01-01  13.556550
# 19 2022-07-01  18.893737
# 20 2023-01-01  13.796390
# 21 2023-07-01  18.490756
# 22 2024-01-01  13.901692
# 23 2024-07-01  21.149441

# %%
#MODELO

m = Prophet(interval_width=0.80)
start_time = time.time()

for _ in tqdm(range(1), desc="Entrenando modelo Prophet"):
    m.fit(df_biannual)

end_time = time.time()
print(f"\nModelo entrenado en {end_time - start_time:.2f} segundos")
# Out:
# Entrenando modelo Prophet:   0%|          | 0/1 [00:00<?, ?it/s]17:13:55 - cmdstanpy - INFO - Chain [1] start processing
# 17:13:55 - cmdstanpy - INFO - Chain [1] done processing
# Entrenando modelo Prophet: 100%|██████████| 1/1 [00:00<00:00, 14.45it/s]
# Modelo entrenado en 0.08 segundos

# %%
future = m.make_future_dataframe(periods=365)
future.tail()
# Out:
#             ds
# 384 2025-06-27
# 385 2025-06-28
# 386 2025-06-29
# 387 2025-06-30
# 388 2025-07-01

# %%
forecast_biannual = m.predict(future)
forecast_biannual[['ds', 'yhat', 'yhat_lower', 'yhat_upper']].tail()
# Out:
#             ds       yhat  yhat_lower  yhat_upper
# 384 2025-06-27  48.242059   47.489769   49.005648
# 385 2025-06-28  35.108410   34.317545   35.835897
# 386 2025-06-29  25.742725   24.963516   26.444682
# 387 2025-06-30  20.420715   19.660328   21.177954
# 388 2025-07-01  19.304242   18.550394   20.027954

# %%
# Graficar usando Prophet
fig1 = m.plot(forecast_biannual)

# Mostrar la gráfica
plt.show()
# Out:
# /opt/anaconda3/lib/python3.12/site-packages/prophet/plot.py:72: FutureWarning: The behavior of DatetimeProperties.to_pydatetime is deprecated, in a future version this will return a Series containing python datetime objects instead of an ndarray. To retain the old behavior, call `np.array` on the result
#   fcst_t = fcst['ds'].dt.to_pydatetime()
# /opt/anaconda3/lib/python3.12/site-packages/prophet/plot.py:73: FutureWarning: The behavior of DatetimeProperties.to_pydatetime is deprecated, in a future version this will return a Series containing python datetime objects instead of an ndarray. To retain the old behavior, call `np.array` on the result
#   ax.plot(m.history['ds'].dt.to_pydatetime(), m.history['y'], 'k.',

# %%
fig2 = m.plot_components(forecast_biannual)
# Out:
# /opt/anaconda3/lib/python3.12/site-packages/prophet/plot.py:228: FutureWarning: The behavior of DatetimeProperties.to_pydatetime is deprecated, in a future version this will return a Series containing python datetime objects instead of an ndarray. To retain the old behavior, call `np.array` on the result
#   fcst_t = fcst['ds'].dt.to_pydatetime()
# /opt/anaconda3/lib/python3.12/site-packages/prophet/plot.py:351: FutureWarning: The behavior of DatetimeProperties.to_pydatetime is deprecated, in a future version this will return a Series containing python datetime objects instead of an ndarray. To retain the old behavior, call `np.array` on the result
#   df_y['ds'].dt.to_pydatetime(), seas[name], ls='-', c='#0072B2')
# /opt/anaconda3/lib/python3.12/site-packages/prophet/plot.py:354: FutureWarning: The behavior of DatetimeProperties.to_pydatetime is deprecated, in a future version this will return a Series containing python datetime objects instead of an ndarray. To retain the old behavior, call `np.array` on the result
#   df_y['ds'].dt.to_pydatetime(), seas[name + '_lower'],

# %%
joblib.dump(forecast_biannual, 'f_prophet_biannual.pkl')

print("Modelo guardado con joblib")
# Out:
# Modelo guardado con joblib

# %% [markdown]
# # TRIMESTRAL:

# %%
df['trimestre'] = df['fecha'].dt.to_period('Q').apply(lambda r: r.start_time)

# %%
df["trimestre"]
# Out:
# 0         2013-01-01
# 1         2013-01-01
# 2         2013-01-01
# 3         2013-01-01
# 4         2013-01-01
#              ...
# 7336000   2024-10-01
# 7336001   2024-10-01
# 7336002   2024-10-01
# 7336003   2024-10-01
# 7336004   2024-10-01
# Name: trimestre, Length: 7336005, dtype: datetime64[ns]

# %%
df_quarterly = df.groupby("trimestre").agg({"tmed":"mean"}).reset_index()
df_quarterly
# Out:
#     trimestre       tmed
# 0  2013-01-01   8.819638
# 1  2013-04-01  15.011527
# 2  2013-07-01  22.414274
# 3  2013-10-01  11.868290
# 4  2014-01-01   9.551493
# 5  2014-04-01  16.970295
# 6  2014-07-01  21.681875
# 7  2014-10-01  12.966418
# 8  2015-01-01   8.788659
# 9  2015-04-01  17.586427
# 10 2015-07-01  22.292992
# 11 2015-10-01  13.375029
# 12 2016-01-01   9.699380
# 13 2016-04-01  16.032528
# 14 2016-07-01  22.826936
# 15 2016-10-01  12.487261
# 16 2017-01-01   9.707947
# 17 2017-04-01  18.096089
# 18 2017-07-01  22.145442
# 19 2017-10-01  12.584619
# 20 2018-01-01   8.558299
# 21 2018-04-01  16.070484
# 22 2018-07-01  22.823935
# 23 2018-10-01  12.399236
# 24 2019-01-01   9.797328
# 25 2019-04-01  16.198272
# 26 2019-07-01  22.454223
# 27 2019-10-01  12.767573
# 28 2020-01-01  10.568246
# 29 2020-04-01  17.215713
# 30 2020-07-01  22.708471
# 31 2020-10-01  12.216888
# 32 2021-01-01   9.739334
# 33 2021-04-01  16.351448
# 34 2021-07-01  22.209033
# 35 2021-10-01  12.244028
# 36 2022-01-01   9.666402
# 37 2022-04-01  17.438189
# 38 2022-07-01  23.404290
# 39 2022-10-01  14.373873
# 40 2023-01-01   9.768641
# 41 2023-04-01  17.814521
# 42 2023-07-01  23.241075
# 43 2023-10-01  13.755637
# 44 2024-01-01  11.002871
# 45 2024-04-01  16.810542
# 46 2024-07-01  22.666505
# 47 2024-10-01  16.739681

# %%
df_quarterly = preparar_data(df_quarterly,"trimestre","tmed")
df_quarterly
# Out:
#            ds          y
# 0  2013-01-01   8.819638
# 1  2013-04-01  15.011527
# 2  2013-07-01  22.414274
# 3  2013-10-01  11.868290
# 4  2014-01-01   9.551493
# 5  2014-04-01  16.970295
# 6  2014-07-01  21.681875
# 7  2014-10-01  12.966418
# 8  2015-01-01   8.788659
# 9  2015-04-01  17.586427
# 10 2015-07-01  22.292992
# 11 2015-10-01  13.375029
# 12 2016-01-01   9.699380
# 13 2016-04-01  16.032528
# 14 2016-07-01  22.826936
# 15 2016-10-01  12.487261
# 16 2017-01-01   9.707947
# 17 2017-04-01  18.096089
# 18 2017-07-01  22.145442
# 19 2017-10-01  12.584619
# 20 2018-01-01   8.558299
# 21 2018-04-01  16.070484
# 22 2018-07-01  22.823935
# 23 2018-10-01  12.399236
# 24 2019-01-01   9.797328
# 25 2019-04-01  16.198272
# 26 2019-07-01  22.454223
# 27 2019-10-01  12.767573
# 28 2020-01-01  10.568246
# 29 2020-04-01  17.215713
# 30 2020-07-01  22.708471
# 31 2020-10-01  12.216888
# 32 2021-01-01   9.739334
# 33 2021-04-01  16.351448
# 34 2021-07-01  22.209033
# 35 2021-10-01  12.244028
# 36 2022-01-01   9.666402
# 37 2022-04-01  17.438189
# 38 2022-07-01  23.404290
# 39 2022-10-01  14.373873
# 40 2023-01-01   9.768641
# 41 2023-04-01  17.814521
# 42 2023-07-01  23.241075
# 43 2023-10-01  13.755637
# 44 2024-01-01  11.002871
# 45 2024-04-01  16.810542
# 46 2024-07-01  22.666505
# 47 2024-10-01  16.739681

# %%
#MODELO

m = Prophet(interval_width=0.80)
start_time = time.time()

for _ in tqdm(range(1), desc="Entrenando modelo Prophet"):
    m.fit(df_quarterly)

end_time = time.time()
print(f"\nModelo entrenado en {end_time - start_time:.2f} segundos")
# Out:
# Entrenando modelo Prophet:   0%|          | 0/1 [00:00<?, ?it/s]17:16:00 - cmdstanpy - INFO - Chain [1] start processing
# 17:16:00 - cmdstanpy - INFO - Chain [1] done processing
# Entrenando modelo Prophet: 100%|██████████| 1/1 [00:00<00:00, 10.61it/s]
# Modelo entrenado en 0.10 segundos

# %%
future = m.make_future_dataframe(periods=365)
future.tail()
# Out:
#             ds
# 408 2025-09-27
# 409 2025-09-28
# 410 2025-09-29
# 411 2025-09-30
# 412 2025-10-01

# %%
forecast_quarterly = m.predict(future)
forecast_quarterly[['ds', 'yhat', 'yhat_lower', 'yhat_upper']].tail()
# Out:
#             ds       yhat  yhat_lower  yhat_upper
# 408 2025-09-27  40.506419   39.586006   41.342201
# 409 2025-09-28  28.914503   28.022698   29.714908
# 410 2025-09-29  20.493160   19.622055   21.343962
# 411 2025-09-30  15.525794   14.655936   16.435266
# 412 2025-10-01  14.220547   13.355634   15.155912

# %%
# Graficar usando Prophet
fig1 = m.plot(forecast_quarterly)

# Mostrar la gráfica
plt.show()
# Out:
# /opt/anaconda3/lib/python3.12/site-packages/prophet/plot.py:72: FutureWarning: The behavior of DatetimeProperties.to_pydatetime is deprecated, in a future version this will return a Series containing python datetime objects instead of an ndarray. To retain the old behavior, call `np.array` on the result
#   fcst_t = fcst['ds'].dt.to_pydatetime()
# /opt/anaconda3/lib/python3.12/site-packages/prophet/plot.py:73: FutureWarning: The behavior of DatetimeProperties.to_pydatetime is deprecated, in a future version this will return a Series containing python datetime objects instead of an ndarray. To retain the old behavior, call `np.array` on the result
#   ax.plot(m.history['ds'].dt.to_pydatetime(), m.history['y'], 'k.',

# %%
fig2 = m.plot_components(forecast_quarterly)
# Out:
# /opt/anaconda3/lib/python3.12/site-packages/prophet/plot.py:228: FutureWarning: The behavior of DatetimeProperties.to_pydatetime is deprecated, in a future version this will return a Series containing python datetime objects instead of an ndarray. To retain the old behavior, call `np.array` on the result
#   fcst_t = fcst['ds'].dt.to_pydatetime()
# /opt/anaconda3/lib/python3.12/site-packages/prophet/plot.py:351: FutureWarning: The behavior of DatetimeProperties.to_pydatetime is deprecated, in a future version this will return a Series containing python datetime objects instead of an ndarray. To retain the old behavior, call `np.array` on the result
#   df_y['ds'].dt.to_pydatetime(), seas[name], ls='-', c='#0072B2')
# /opt/anaconda3/lib/python3.12/site-packages/prophet/plot.py:354: FutureWarning: The behavior of DatetimeProperties.to_pydatetime is deprecated, in a future version this will return a Series containing python datetime objects instead of an ndarray. To retain the old behavior, call `np.array` on the result
#   df_y['ds'].dt.to_pydatetime(), seas[name + '_lower'],

# %%
joblib.dump(forecast_quarterly, 'f_prophet_quarterly.pkl')

print("Modelo guardado con joblib")
# Out:
# Modelo guardado con joblib

# %% [markdown]
# # MENSUAL:

# %%
df['mes'] = df['fecha'].dt.to_period('M').apply(lambda r: r.start_time)

# %%
df['mes']
# Out:
# 0         2013-01-01
# 1         2013-01-01
# 2         2013-01-01
# 3         2013-01-01
# 4         2013-01-01
#              ...
# 7336000   2024-11-01
# 7336001   2024-11-01
# 7336002   2024-11-01
# 7336003   2024-11-01
# 7336004   2024-11-01
# Name: mes, Length: 7336005, dtype: datetime64[ns]

# %%
df_monthly = df.groupby("mes").agg({"tmed":"mean"}).reset_index()
df_monthly
# Out:
#            mes       tmed
# 0   2013-01-01   8.371864
# 1   2013-02-01   7.588383
# 2   2013-03-01  10.365606
# 3   2013-04-01  12.464401
# 4   2013-05-01  13.957410
# ..         ...        ...
# 138 2024-07-01  24.036916
# 139 2024-08-01  24.672682
# 140 2024-09-01  19.162857
# 141 2024-10-01  16.764565
# 142 2024-11-01  15.955422
#
# [143 rows x 2 columns]

# %%
df_monthly = preparar_data(df_monthly,"mes","tmed")
df_monthly
# Out:
#             ds          y
# 0   2013-01-01   8.371864
# 1   2013-02-01   7.588383
# 2   2013-03-01  10.365606
# 3   2013-04-01  12.464401
# 4   2013-05-01  13.957410
# ..         ...        ...
# 138 2024-07-01  24.036916
# 139 2024-08-01  24.672682
# 140 2024-09-01  19.162857
# 141 2024-10-01  16.764565
# 142 2024-11-01  15.955422
#
# [143 rows x 2 columns]

# %%
#MODELO

m = Prophet(interval_width=0.80)
start_time = time.time()

for _ in tqdm(range(1), desc="Entrenando modelo Prophet"):
    m.fit(df_monthly)

end_time = time.time()
print(f"\nModelo entrenado en {end_time - start_time:.2f} segundos")
# Out:
# Entrenando modelo Prophet:   0%|          | 0/1 [00:00<?, ?it/s]17:18:05 - cmdstanpy - INFO - Chain [1] start processing
# 17:18:05 - cmdstanpy - INFO - Chain [1] done processing
# Entrenando modelo Prophet: 100%|██████████| 1/1 [00:00<00:00, 16.78it/s]
# Modelo entrenado en 0.06 segundos

# %%
future = m.make_future_dataframe(periods=365)
future.tail()
# Out:
#             ds
# 503 2025-10-28
# 504 2025-10-29
# 505 2025-10-30
# 506 2025-10-31
# 507 2025-11-01

# %%
forecast_monthly = m.predict(future)
forecast_monthly[['ds', 'yhat', 'yhat_lower', 'yhat_upper']].tail()
# Out:
#             ds       yhat  yhat_lower  yhat_upper
# 503 2025-10-28   9.960163    8.599318   11.255451
# 504 2025-10-29  10.686704    9.308873   12.043891
# 505 2025-10-30  11.452233   10.215375   12.773228
# 506 2025-10-31  12.245516   10.958016   13.572076
# 507 2025-11-01  13.054774   11.811641   14.365291

# %%
# Graficar usando Prophet
fig1 = m.plot(forecast_monthly)

# Mostrar la gráfica
plt.show()
# Out:
# /opt/anaconda3/lib/python3.12/site-packages/prophet/plot.py:72: FutureWarning: The behavior of DatetimeProperties.to_pydatetime is deprecated, in a future version this will return a Series containing python datetime objects instead of an ndarray. To retain the old behavior, call `np.array` on the result
#   fcst_t = fcst['ds'].dt.to_pydatetime()
# /opt/anaconda3/lib/python3.12/site-packages/prophet/plot.py:73: FutureWarning: The behavior of DatetimeProperties.to_pydatetime is deprecated, in a future version this will return a Series containing python datetime objects instead of an ndarray. To retain the old behavior, call `np.array` on the result
#   ax.plot(m.history['ds'].dt.to_pydatetime(), m.history['y'], 'k.',

# %%
fig2 = m.plot_components(forecast_monthly)
# Out:
# /opt/anaconda3/lib/python3.12/site-packages/prophet/plot.py:228: FutureWarning: The behavior of DatetimeProperties.to_pydatetime is deprecated, in a future version this will return a Series containing python datetime objects instead of an ndarray. To retain the old behavior, call `np.array` on the result
#   fcst_t = fcst['ds'].dt.to_pydatetime()
# /opt/anaconda3/lib/python3.12/site-packages/prophet/plot.py:351: FutureWarning: The behavior of DatetimeProperties.to_pydatetime is deprecated, in a future version this will return a Series containing python datetime objects instead of an ndarray. To retain the old behavior, call `np.array` on the result
#   df_y['ds'].dt.to_pydatetime(), seas[name], ls='-', c='#0072B2')
# /opt/anaconda3/lib/python3.12/site-packages/prophet/plot.py:354: FutureWarning: The behavior of DatetimeProperties.to_pydatetime is deprecated, in a future version this will return a Series containing python datetime objects instead of an ndarray. To retain the old behavior, call `np.array` on the result
#   df_y['ds'].dt.to_pydatetime(), seas[name + '_lower'],

# %%
joblib.dump(forecast_monthly, 'f_prophet_monthly.pkl')

print("Modelo guardado con joblib")
# Out:
# Modelo guardado con joblib

# %% [markdown]
# # SEMANAL:

# %%
df['semana'] = df['fecha'].dt.to_period('W').apply(lambda r: r.start_time)

# %%
df_weekly = df.groupby("semana").agg({"tmed":"mean"}).reset_index()

# %%
df_weekly = preparar_data(df_weekly,"semana","tmed")
df_weekly
# Out:
#             ds          y
# 0   2012-12-31   8.512068
# 1   2013-01-07   7.987963
# 2   2013-01-14   8.433796
# 3   2013-01-21   7.484366
# 4   2013-01-28   9.582280
# ..         ...        ...
# 613 2024-09-30  19.037875
# 614 2024-10-07  17.418297
# 615 2024-10-14  17.105175
# 616 2024-10-21  15.004087
# 617 2024-10-28  14.962961
#
# [618 rows x 2 columns]

# %%
#MODELO

m = Prophet(interval_width=0.80)
start_time = time.time()

for _ in tqdm(range(1), desc="Entrenando modelo Prophet"):
    m.fit(df_weekly)

end_time = time.time()
print(f"\nModelo entrenado en {end_time - start_time:.2f} segundos")
# Out:
# Entrenando modelo Prophet:   0%|          | 0/1 [00:00<?, ?it/s]17:20:09 - cmdstanpy - INFO - Chain [1] start processing
# 17:20:09 - cmdstanpy - INFO - Chain [1] done processing
# Entrenando modelo Prophet: 100%|██████████| 1/1 [00:00<00:00, 25.14it/s]
# Modelo entrenado en 0.04 segundos

# %%
future = m.make_future_dataframe(periods=365)
future.tail()
# Out:
#             ds
# 978 2025-10-24
# 979 2025-10-25
# 980 2025-10-26
# 981 2025-10-27
# 982 2025-10-28

# %%
forecast_weekly = m.predict(future)
forecast_weekly[['ds', 'yhat', 'yhat_lower', 'yhat_upper']].tail()
# Out:
#             ds       yhat  yhat_lower  yhat_upper
# 978 2025-10-24  15.963497   13.855563   18.095910
# 979 2025-10-25  15.795046   13.712539   17.759445
# 980 2025-10-26  15.627986   13.628124   17.582825
# 981 2025-10-27  15.462085   13.483385   17.471181
# 982 2025-10-28  15.297016   13.222264   17.356204

# %%
# Graficar usando Prophet
fig1 = m.plot(forecast_weekly)

# Mostrar la gráfica
plt.show()
# Out:
# /opt/anaconda3/lib/python3.12/site-packages/prophet/plot.py:72: FutureWarning: The behavior of DatetimeProperties.to_pydatetime is deprecated, in a future version this will return a Series containing python datetime objects instead of an ndarray. To retain the old behavior, call `np.array` on the result
#   fcst_t = fcst['ds'].dt.to_pydatetime()
# /opt/anaconda3/lib/python3.12/site-packages/prophet/plot.py:73: FutureWarning: The behavior of DatetimeProperties.to_pydatetime is deprecated, in a future version this will return a Series containing python datetime objects instead of an ndarray. To retain the old behavior, call `np.array` on the result
#   ax.plot(m.history['ds'].dt.to_pydatetime(), m.history['y'], 'k.',

# %%
fig2 = m.plot_components(forecast_weekly)
# Out:
# /opt/anaconda3/lib/python3.12/site-packages/prophet/plot.py:228: FutureWarning: The behavior of DatetimeProperties.to_pydatetime is deprecated, in a future version this will return a Series containing python datetime objects instead of an ndarray. To retain the old behavior, call `np.array` on the result
#   fcst_t = fcst['ds'].dt.to_pydatetime()
# /opt/anaconda3/lib/python3.12/site-packages/prophet/plot.py:351: FutureWarning: The behavior of DatetimeProperties.to_pydatetime is deprecated, in a future version this will return a Series containing python datetime objects instead of an ndarray. To retain the old behavior, call `np.array` on the result
#   df_y['ds'].dt.to_pydatetime(), seas[name], ls='-', c='#0072B2')
# /opt/anaconda3/lib/python3.12/site-packages/prophet/plot.py:354: FutureWarning: The behavior of DatetimeProperties.to_pydatetime is deprecated, in a future version this will return a Series containing python datetime objects instead of an ndarray. To retain the old behavior, call `np.array` on the result
#   df_y['ds'].dt.to_pydatetime(), seas[name + '_lower'],

# %%
joblib.dump(forecast_weekly, 'f_prophet_weekly.pkl')

print("Modelo guardado con joblib")
# Out:
# Modelo guardado con joblib

# %% [markdown]
# # DIARIO:

# %%
df['dia'] = df['fecha'].dt.to_period('D').apply(lambda r: r.start_time)
df['dia']
# Out:
# 0         2013-01-01
# 1         2013-01-01
# 2         2013-01-01
# 3         2013-01-01
# 4         2013-01-01
#              ...
# 7336000   2024-11-01
# 7336001   2024-11-01
# 7336002   2024-11-01
# 7336003   2024-11-01
# 7336004   2024-11-01
# Name: dia, Length: 7336005, dtype: datetime64[ns]

# %%
df_daily = df.groupby("dia").agg({"tmed":"mean"}).reset_index()
df_daily
# Out:
#             dia       tmed
# 0    2013-01-01   8.240339
# 1    2013-01-02   7.839921
# 2    2013-01-03   7.954712
# 3    2013-01-04   8.583443
# 4    2013-01-05   9.326746
# ...         ...        ...
# 4318 2024-10-28  13.507628
# 4319 2024-10-29  14.864982
# 4320 2024-10-30  14.950358
# 4321 2024-10-31  15.548206
# 4322 2024-11-01  15.955422
#
# [4323 rows x 2 columns]

# %%
df_daily = preparar_data(df_daily,"dia","tmed")
df_daily
# Out:
#              ds          y
# 0    2013-01-01   8.240339
# 1    2013-01-02   7.839921
# 2    2013-01-03   7.954712
# 3    2013-01-04   8.583443
# 4    2013-01-05   9.326746
# ...         ...        ...
# 4318 2024-10-28  13.507628
# 4319 2024-10-29  14.864982
# 4320 2024-10-30  14.950358
# 4321 2024-10-31  15.548206
# 4322 2024-11-01  15.955422
#
# [4323 rows x 2 columns]

# %%
#MODELO

m = Prophet(interval_width=0.80)
start_time = time.time()

for _ in tqdm(range(1), desc="Entrenando modelo Prophet"):
    m.fit(df_daily)

end_time = time.time()
print(f"\nModelo entrenado en {end_time - start_time:.2f} segundos")
# Out:
# Entrenando modelo Prophet:   0%|          | 0/1 [00:00<?, ?it/s]17:57:16 - cmdstanpy - INFO - Chain [1] start processing
# 17:57:16 - cmdstanpy - INFO - Chain [1] done processing
# Entrenando modelo Prophet: 100%|██████████| 1/1 [00:00<00:00,  3.46it/s]
# Modelo entrenado en 0.29 segundos

# %%
future = m.make_future_dataframe(periods=365)
future.tail()
# Out:
#              ds
# 4683 2025-10-28
# 4684 2025-10-29
# 4685 2025-10-30
# 4686 2025-10-31
# 4687 2025-11-01

# %%
forecast_daily = m.predict(future)
forecast_daily[['ds', 'yhat', 'yhat_lower', 'yhat_upper']].tail()
# Out:
#              ds       yhat  yhat_lower  yhat_upper
# 4683 2025-10-28  15.538949   12.961018   18.103844
# 4684 2025-10-29  15.447721   12.696706   17.846849
# 4685 2025-10-30  15.339900   12.502871   17.984180
# 4686 2025-10-31  15.116912   12.467018   17.687389
# 4687 2025-11-01  14.862052   12.216004   17.514101

# %%
# Graficar usando Prophet
fig1 = m.plot(forecast_daily)

# Mostrar la gráfica
plt.show()
# Out:
# /opt/anaconda3/lib/python3.12/site-packages/prophet/plot.py:72: FutureWarning: The behavior of DatetimeProperties.to_pydatetime is deprecated, in a future version this will return a Series containing python datetime objects instead of an ndarray. To retain the old behavior, call `np.array` on the result
#   fcst_t = fcst['ds'].dt.to_pydatetime()
# /opt/anaconda3/lib/python3.12/site-packages/prophet/plot.py:73: FutureWarning: The behavior of DatetimeProperties.to_pydatetime is deprecated, in a future version this will return a Series containing python datetime objects instead of an ndarray. To retain the old behavior, call `np.array` on the result
#   ax.plot(m.history['ds'].dt.to_pydatetime(), m.history['y'], 'k.',

# %%
fig2 = m.plot_components(forecast_daily)
# Out:
# /opt/anaconda3/lib/python3.12/site-packages/prophet/plot.py:228: FutureWarning: The behavior of DatetimeProperties.to_pydatetime is deprecated, in a future version this will return a Series containing python datetime objects instead of an ndarray. To retain the old behavior, call `np.array` on the result
#   fcst_t = fcst['ds'].dt.to_pydatetime()
# /opt/anaconda3/lib/python3.12/site-packages/prophet/plot.py:351: FutureWarning: The behavior of DatetimeProperties.to_pydatetime is deprecated, in a future version this will return a Series containing python datetime objects instead of an ndarray. To retain the old behavior, call `np.array` on the result
#   df_y['ds'].dt.to_pydatetime(), seas[name], ls='-', c='#0072B2')
# /opt/anaconda3/lib/python3.12/site-packages/prophet/plot.py:354: FutureWarning: The behavior of DatetimeProperties.to_pydatetime is deprecated, in a future version this will return a Series containing python datetime objects instead of an ndarray. To retain the old behavior, call `np.array` on the result
#   df_y['ds'].dt.to_pydatetime(), seas[name + '_lower'],

# %%
joblib.dump(forecast_daily, 'f_prophet_daily.pkl')

print("Modelo guardado con joblib")
# Out:
# Modelo guardado con joblib
